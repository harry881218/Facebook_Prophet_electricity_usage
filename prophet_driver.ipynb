# %%
from model_util import *

# %%
df_list = data_processing()

# %%
model_li, pred_li, train_li, test_li, mape_li = predict_all_clients(df_list)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp28c2ilhz/82zcxbwd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp28c2ilhz/rckgc47r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84659', 'data', 'file=/tmp/tmp28c2ilhz/82zcxbwd.json', 'init=/tmp/tmp28c2ilhz/rckgc47r.json', 'output', 'file=/tmp/tmp28c2ilhz/prophet_model7luzlsg2/prophet_model-20231109225415.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:54:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:54:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ...

# %%
idx = 350 # index in the list, so MT_001 is idx 0
plot_a_client(idx, train_li, test_li, pred_li)

# %%
client_MAPE(350, mape_li)
# Out:
# 0.11446732929013499

# %%
client_plot_components(350, model_li, pred_li)

# %%
client_to_idx("MT_001")
# Out:
# 0
